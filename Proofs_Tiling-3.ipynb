# %%
from definitions import *
num_cores = multiprocessing.cpu_count()

# %%
Graphs3 = load_plantri(filename='plantri/08pm4c3')
print(f'Loaded {len(Graphs3)} grahps from plantri.')

inputs = tqdm(Graphs3)
if __name__ == "__main__":
    processed_list = Parallel(n_jobs=num_cores)(delayed(add_distinguished)(G) for G in inputs)
Graphs3 = [G for DGraph in processed_list for G in DGraph]
print(f'Constructed {len(Graphs3)} graphs with a distinguished vertex.')

inputs = tqdm(Graphs3)
if __name__ == "__main__":
    processed_list = Parallel(n_jobs=num_cores)(delayed(first_filter)(G) for G in inputs)
Graphs3 = [Graphs3[i] for i in range(len(Graphs3)) if processed_list[i]]
print(f'There are {len(Graphs3)} graphs left after first filter.')

inputs = tqdm(Graphs3)
if __name__ == "__main__":
    processed_list = Parallel(n_jobs=num_cores)(delayed(has_min_deg)(G,5) for G in inputs)
Graphs3_5 = [Graphs3[i] for i in range(len(Graphs3)) if processed_list[i]]
print(f'There are {len(Graphs3_5)} pentagonal graphs.')

inputs = tqdm(Graphs3)
if __name__ == "__main__":
    processed_list = Parallel(n_jobs=num_cores)(delayed(second_filter)(G) for G in inputs)
Graphs3_4 = [Graphs3[i] for i in range(len(Graphs3)) if processed_list[i]]
print(f'There are {len(Graphs3_4)} quadrilateral graphs left after second filter.')
save_data(Graphs3_4,'grahps/filtered_3_4.txt')
# Out:
# Loaded 4 grahps from plantri.
# 100%|███████████████████████████████████████████| 4/4 [00:00<00:00, 285.89it/s]
# Constructed 3 graphs with a distinguished vertex.
# 100%|██████████████████████████████████████████| 3/3 [00:00<00:00, 1500.82it/s]
# There are 3 graphs left after first filter.
# 100%|██████████████████████████████████████████| 3/3 [00:00<00:00, 1501.18it/s]
# There are 0 pentagonal graphs.
# 100%|██████████████████████████████████████████| 3/3 [00:00<00:00, 1500.82it/s]
# There are 1 quadrilateral graphs left after second filter.

# %%
save_ang_perms(4,'4_perms.txt')
Graphs3_4 = load_data('grahps/filtered_3_4.txt')

print('Incidence graph')
G=Graphs3_4[0]
G.draw()

search(0,G,'4_perms.txt',PrintProof=True)
# Out:
# Incidence graph
# Assuming T has labeling: aaao
#
#   Assigning the angle in tile 6 incident to tiles [2, 1, 6]
#     - to vertex 0 of T which has angle-type 'a'
#       Only this vertex of T is considered, cyclic permutations of this labeling are considered separately
#       Impossible: Sum of angles at this tiling-vertex would be too small
#   Possible assignments: []
#
# Found 0 possible solutions.
#
# -------------------------------------------------
#
# Assuming T has labeling: aaro
#
#   Assigning the angle in tile 6 incident to tiles [2, 1, 6]
#     - to vertex 0 of T which has angle-type 'a'
#       Only this vertex of T is considered, cyclic permutations of this labeling are considered separately
#       Impossible: Sum of angles at this tiling-vertex would be too small
#   Possible assignments: []
#
# Found 0 possible solutions.
#
# -------------------------------------------------
#
# Assuming T has labeling: aaoa
#
#   Assigning the angle in tile 6 incident to tiles [2, 1, 6]
#     - to vertex 0 of T which has angle-type 'a'
#       Only this vertex of T is considered, cyclic permutations of this labeling are considered separately
#       Impossible: Sum of angles at this tiling-vertex would be too small
#   Possible assignments: []
#
# Found 0 possible solutions.
#
# -------------------------------------------------
#
# Assuming T has labeling: aaor
#
#   Assigning the angle in tile 6 incident to tiles [2, 1, 6]
#     - to vertex 0 of T which has angle-type 'a'
#       Only this vertex of T is considered, cyclic permutations of this labeling are considered separately
#       Impossible: Sum of angles at this tiling-vertex would be too small
#   Possible assignments: []
#
# Found 0 possible solutions.
#
# -------------------------------------------------
#
# Assuming T has labeling: aaoo
#
#   Assigning the angle in tile 6 incident to tiles [2, 1, 6]
#     - to vertex 0 of T which has angle-type 'a'
#       Only this vertex of T is considered, cyclic permutations of this labeling are considered separately
#       Impossible: Sum of angles at this tiling-vertex would be too small
#   Possible assignments: []
#
# Found 0 possible solutions.
#
# -------------------------------------------------
#
# Assuming T has labeling: arao
#
#   Assigning the angle in tile 6 incident to tiles [2, 1, 6]
#     - to vertex 0 of T which has angle-type 'a'
#       Only this vertex of T is considered, cyclic permutations of this labeling are considered separately
#       Impossible: Sum of angles at this tiling-vertex would be too small
#   Possible assignments: []
#
# Found 0 possible solutions.
#
# -------------------------------------------------
#
# Assuming T has labeling: aror
#
#   Assigning the angle in tile 6 incident to tiles [2, 1, 6]
#     - to vertex 0 of T which has angle-type 'a'
#       Only this vertex of T is considered, cyclic permutations of this labeling are considered separately
#       Impossible: Sum of angles at this tiling-vertex would be too small
#   Possible assignments: []
#
# Found 0 possible solutions.
#
# -------------------------------------------------
#
# Assuming T has labeling: aroo
#
#   Assigning the angle in tile 6 incident to tiles [2, 1, 6]
#     - to vertex 0 of T which has angle-type 'a'
#       Only this vertex of T is considered, cyclic permutations of this labeling are considered separately
#       Impossible: Sum of angles at this tiling-vertex would be too small
#   Possible assignments: []
#
# Found 0 possible solutions.
#
# -------------------------------------------------
#
# Assuming T has labeling: aoao
#
#   Assigning the angle in tile 6 incident to tiles [2, 1, 6]
#     - to vertex 0 of T which has angle-type 'a'
#       Only this vertex of T is considered, cyclic permutations of this labeling are considered separately
#       Impossible: Sum of angles at this tiling-vertex would be too small
#   Possible assignments: []
#
# Found 0 possible solutions.
#
# -------------------------------------------------
#
# Assuming T has labeling: aoro
#
#   Assigning the angle in tile 6 incident to tiles [2, 1, 6]
#     - to vertex 0 of T which has angle-type 'a'
#       Only this vertex of T is considered, cyclic permutations of this labeling are considered separately
#       Impossible: Sum of angles at this tiling-vertex would be too small
#   Possible assignments: []
#
# Found 0 possible solutions.
#
# -------------------------------------------------
#
# Assuming T has labeling: aooo
#
#   Assigning the angle in tile 6 incident to tiles [2, 1, 6]
#     - to vertex 0 of T which has angle-type 'a'
#       Only this vertex of T is considered, cyclic permutations of this labeling are considered separately
#       Impossible: Sum of angles at this tiling-vertex would be too small
#   Possible assignments: []
#
# Found 0 possible solutions.
#
# -------------------------------------------------
#
# Assuming T has labeling: raao
#
#   Assigning the angle in tile 6 incident to tiles [2, 1, 6]
#     - to vertex 0 of T which has angle-type 'r'
#       Only this vertex of T is considered, cyclic permutations of this labeling are considered separately
#   Possible assignments: [0]
#
#   Assign 0 to (6, [2, 1, 6])
#     New angle equation: +x0-90=0
#     Reduced angle equations:
#       {x0 = 90.0, x1 = -x2 - x3 + 270.0}
#     No new side equation
#
# This case has the following possibilities:
#   Assigning the angle in tile 6 incident to tiles [3, 2, 6, 7]
#     - to vertex 1 of T which has angle-type 'a'
#     - to vertex 2 of T which has angle-type 'a'
#       Impossible: The angles of this tile would be in the wrong order
#     - to vertex 3 of T which has angle-type 'o'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#   Possible assignments: [1]
#
# Case 1.
#   Assign 1 to (6, [3, 2, 6, 7])
#     No new angle equation
#     New side equation: +x0-1.0=0
#     Reduced side equations:
#       {x0 = 1.00}
#
# Case 1. has the following possibilities:
#   Assigning the angle in tile 7 incident to tiles [3, 2, 6, 7]
#     - to vertex 0 of T which has angle-type 'r'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#     - to vertex 1 of T which has angle-type 'a'
#     - to vertex 2 of T which has angle-type 'a'
#     - to vertex 3 of T which has angle-type 'o'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#   Possible assignments: [1, 2]
#
# Case 1.1.
#   Assign 1 to (7, [3, 2, 6, 7])
#     New angle equation: +x1+x1-90=0
#     Reduced angle equations:
#       {x0 = 90.0, x1 = 45.0, x2 = 225.0 - x3}
#     No new side equation
#
# Case 1.2.
#   Assign 2 to (7, [3, 2, 6, 7])
#     New angle equation: +x1+x2-90=0
#     Reduced angle equations:
#       {x0 = 90.0, x1 = 90.0 - x2, x3 = 180.0}
#     Impossible: Angle-type of angle 3 is not 'o' (value 180.0)
#
# Case 1.1. has the following possibilities:
#   Assigning the angle in tile 7 incident to tiles [4, 3, 7]
#     - to vertex 0 of T which has angle-type 'r'
#     - to vertex 2 of T which has angle-type 'a'
#       Impossible: Sum of angles at this tiling-vertex would be too small
#     - to vertex 3 of T which has angle-type 'o'
#       Impossible: The angles of this tile would be in the wrong order
#   Possible assignments: [0]
#
# Case 1.1.1.
#   Assign 0 to (7, [4, 3, 7])
#     New angle equation: +x0-90=0
#     Reduced angle equations:
#       {x0 = 90.0, x1 = 45.0, x2 = 225.0 - x3}
#     New side equation: +x0-1.0=0
#     Reduced side equations:
#       {x0 = 1.00}
#
# Case 1.1.1. has the following possibilities:
#   Assigning the angle in tile 5 incident to tiles [1, 4, 5]
#     - to vertex 0 of T which has angle-type 'r'
#     - to vertex 1 of T which has angle-type 'a'
#       Impossible: Sum of angles at this tiling-vertex would be too small
#     - to vertex 2 of T which has angle-type 'a'
#       Impossible: Sum of angles at this tiling-vertex would be too small
#     - to vertex 3 of T which has angle-type 'o'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#   Possible assignments: [0]
#
# Case 1.1.1.1.
#   Assign 0 to (5, [1, 4, 5])
#     New angle equation: +x0-90=0
#     Reduced angle equations:
#       {x0 = 90.0, x1 = 45.0, x2 = 225.0 - x3}
#     No new side equation
#
# Case 1.1.1.1. has the following possibilities:
#   Assigning the angle in tile 5 incident to tiles [1, 5, 6]
#     - to vertex 1 of T which has angle-type 'a'
#     - to vertex 2 of T which has angle-type 'a'
#       Impossible: The angles of this tile would be in the wrong order
#     - to vertex 3 of T which has angle-type 'o'
#   Possible assignments: [1, 3]
#
# Case 1.1.1.1.1.
#   Assign 1 to (5, [1, 5, 6])
#     No new angle equation
#     No new side equation
#
# Case 1.1.1.1.2.
#   Assign 3 to (5, [1, 5, 6])
#     No new angle equation
#     No new side equation
#
# Case 1.1.1.1.1. has the following possibilities:
#   Assigning the angle in tile 6 incident to tiles [1, 5, 6]
#     - to vertex 2 of T which has angle-type 'a'
#       The angles of this tile would be in the wrong order
#     - to vertex 3 of T which has angle-type 'o'
#   Possible assignments: [3]
#
# Case 1.1.1.1.1.1.
#   Assign 3 to (6, [1, 5, 6])
#     New angle equation: +x1+x3-180=0
#     Reduced angle equations:
#       {x0 = 90.0, x1 = 45.0, x2 = 90.0, x3 = 135.0}
#     Impossible: Angle-type of angle 2 is not 'a' (value 90.0)
#
# Case 1.1.1.1.2. has the following possibilities:
#   Assigning the angle in tile 6 incident to tiles [1, 5, 6]
#     - to vertex 2 of T which has angle-type 'a'
#       The angles of this tile would be in the wrong order
#     - to vertex 3 of T which has angle-type 'o'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#   Possible assignments: []
#
# Found 0 possible solutions.
#
# -------------------------------------------------
#
# Assuming T has labeling: raro
#
#   Assigning the angle in tile 6 incident to tiles [2, 1, 6]
#     - to vertex 0 of T which has angle-type 'r'
#       Only this vertex of T is considered, cyclic permutations of this labeling are considered separately
#   Possible assignments: [0]
#
#   Assign 0 to (6, [2, 1, 6])
#     New angle equation: +x0-90=0
#     Reduced angle equations:
#       {x0 = 90.0, x1 = -x2 - x3 + 270.0}
#     No new side equation
#
# This case has the following possibilities:
#   Assigning the angle in tile 6 incident to tiles [3, 2, 6, 7]
#     - to vertex 1 of T which has angle-type 'a'
#     - to vertex 2 of T which has angle-type 'r'
#       Impossible: The angles of this tile would be in the wrong order
#     - to vertex 3 of T which has angle-type 'o'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#   Possible assignments: [1]
#
# Case 1.
#   Assign 1 to (6, [3, 2, 6, 7])
#     No new angle equation
#     New side equation: +x0-1.0=0
#     Reduced side equations:
#       {x0 = 1.00}
#
# Case 1. has the following possibilities:
#   Assigning the angle in tile 7 incident to tiles [3, 2, 6, 7]
#     - to vertex 0 of T which has angle-type 'r'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#     - to vertex 1 of T which has angle-type 'a'
#     - to vertex 2 of T which has angle-type 'r'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#     - to vertex 3 of T which has angle-type 'o'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#   Possible assignments: [1]
#
# Case 1.1.
#   Assign 1 to (7, [3, 2, 6, 7])
#     New angle equation: +x1+x1-90=0
#     Reduced angle equations:
#       {x0 = 90.0, x1 = 45.0, x2 = 225.0 - x3}
#     No new side equation
#
# Case 1.1. has the following possibilities:
#   Assigning the angle in tile 7 incident to tiles [4, 3, 7]
#     - to vertex 0 of T which has angle-type 'r'
#     - to vertex 2 of T which has angle-type 'r'
#     - to vertex 3 of T which has angle-type 'o'
#       Impossible: The angles of this tile would be in the wrong order
#   Possible assignments: [0, 2]
#
# Case 1.1.1.
#   Assign 0 to (7, [4, 3, 7])
#     New angle equation: +x0-90=0
#     Reduced angle equations:
#       {x0 = 90.0, x1 = 45.0, x2 = 225.0 - x3}
#     New side equation: +x0-1.0=0
#     Reduced side equations:
#       {x0 = 1.00}
#
# Case 1.1.2.
#   Assign 2 to (7, [4, 3, 7])
#     New angle equation: +x2-90=0
#     Reduced angle equations:
#       {x0 = 90.0, x1 = 45.0, x2 = 90.0, x3 = 135.0}
#     New side equation: +x1-1.0=0
#     Reduced side equations:
#       {x0 = 1.00, x1 = 1.00}
#     Impossible: Labeling raro with acute angle 45.0 and sides [1.0, 1.0, 'Not Solved', 'Not Solved'] has area 0.41421356237309503 instead of 0.3333333333333333
#
# Case 1.1.1. has the following possibilities:
#   Assigning the angle in tile 5 incident to tiles [1, 4, 5]
#     - to vertex 0 of T which has angle-type 'r'
#     - to vertex 1 of T which has angle-type 'a'
#       Impossible: Sum of angles at this tiling-vertex would be too small
#     - to vertex 2 of T which has angle-type 'r'
#     - to vertex 3 of T which has angle-type 'o'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#   Possible assignments: [0, 2]
#
# Case 1.1.1.1.
#   Assign 0 to (5, [1, 4, 5])
#     New angle equation: +x0-90=0
#     Reduced angle equations:
#       {x0 = 90.0, x1 = 45.0, x2 = 225.0 - x3}
#     No new side equation
#
# Case 1.1.1.2.
#   Assign 2 to (5, [1, 4, 5])
#     New angle equation: +x2-90=0
#     Reduced angle equations:
#       {x0 = 90.0, x1 = 45.0, x2 = 90.0, x3 = 135.0}
#     No new side equation
#
# Case 1.1.1.1. has the following possibilities:
#   Assigning the angle in tile 5 incident to tiles [1, 5, 6]
#     - to vertex 1 of T which has angle-type 'a'
#     - to vertex 2 of T which has angle-type 'r'
#       Impossible: The angles of this tile would be in the wrong order
#     - to vertex 3 of T which has angle-type 'o'
#   Possible assignments: [1, 3]
#
# Case 1.1.1.1.1.
#   Assign 1 to (5, [1, 5, 6])
#     No new angle equation
#     No new side equation
#
# Case 1.1.1.1.2.
#   Assign 3 to (5, [1, 5, 6])
#     No new angle equation
#     No new side equation
#
# Case 1.1.1.2. has the following possibilities:
#   Assigning the angle in tile 5 incident to tiles [1, 5, 6]
#     - to vertex 0 of T which has angle-type 'r'
#       Impossible: The angles of this tile would be in the wrong order
#     - to vertex 1 of T which has angle-type 'a'
#     - to vertex 3 of T which has angle-type 'o'
#   Possible assignments: [1, 3]
#
# Case 1.1.1.2.1.
#   Assign 1 to (5, [1, 5, 6])
#     No new angle equation
#     No new side equation
#
# Case 1.1.1.2.2.
#   Assign 3 to (5, [1, 5, 6])
#     No new angle equation
#     No new side equation
#
# Case 1.1.1.1.1. has the following possibilities:
#   Assigning the angle in tile 6 incident to tiles [1, 5, 6]
#     - to vertex 2 of T which has angle-type 'r'
#       The angles of this tile would be in the wrong order
#     - to vertex 3 of T which has angle-type 'o'
#   Possible assignments: [3]
#
# Case 1.1.1.1.1.1.
#   Assign 3 to (6, [1, 5, 6])
#     New angle equation: +x1+x3-180=0
#     Reduced angle equations:
#       {x0 = 90.0, x1 = 45.0, x2 = 90.0, x3 = 135.0}
#     New side equation: +x0+x3-1.0=0
#     Reduced side equations:
#       {x0 = 1.00, x3 = 0.0}
#     Impossible: Side equations have no positive solutions
#
# Case 1.1.1.1.2. has the following possibilities:
#   Assigning the angle in tile 6 incident to tiles [1, 5, 6]
#     - to vertex 2 of T which has angle-type 'r'
#       The angles of this tile would be in the wrong order
#     - to vertex 3 of T which has angle-type 'o'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#   Possible assignments: []
#
# Case 1.1.1.2.1. has the following possibilities:
#   Assigning the angle in tile 6 incident to tiles [1, 5, 6]
#     - to vertex 2 of T which has angle-type 'r'
#       The angles of this tile would be in the wrong order
#     - to vertex 3 of T which has angle-type 'o'
#   Possible assignments: [3]
#
# Case 1.1.1.2.1.1.
#   Assign 3 to (6, [1, 5, 6])
#     New angle equation: +x1+x3-180=0
#     Reduced angle equations:
#       {x0 = 90.0, x1 = 45.0, x2 = 90.0, x3 = 135.0}
#     New side equation: +x1+x3-1.0=0
#     Reduced side equations:
#       {x0 = 1.00, x1 = 1.0 - x3}
#
# Case 1.1.1.2.2. has the following possibilities:
#   Assigning the angle in tile 6 incident to tiles [1, 5, 6]
#     - to vertex 2 of T which has angle-type 'r'
#       The angles of this tile would be in the wrong order
#     - to vertex 3 of T which has angle-type 'o'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#   Possible assignments: []
#
# Case 1.1.1.2.1.1. has the following possibilities:
#   Assigning the angle in tile 7 incident to tiles [4, 7, 5]
#     - to vertex 2 of T which has angle-type 'r'
#       Impossible: The angles of this tile would be in the wrong order
#     - to vertex 3 of T which has angle-type 'o'
#   Possible assignments: [3]
#
# Case 1.1.1.2.1.1.1.
#   Assign 3 to (7, [4, 7, 5])
#     No new angle equation
#     No new side equation
#
# Case 1.1.1.2.1.1.1. has the following possibilities:
#   Assigning the angle in tile 5 incident to tiles [4, 7, 5]
#     - to vertex 0 of T which has angle-type 'r'
#       The angles of this tile would be in the wrong order
#     - to vertex 3 of T which has angle-type 'o'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#   Possible assignments: []
#
# Found 0 possible solutions.
#
# -------------------------------------------------
#
# Assuming T has labeling: raoa
#
#   Assigning the angle in tile 6 incident to tiles [2, 1, 6]
#     - to vertex 0 of T which has angle-type 'r'
#       Only this vertex of T is considered, cyclic permutations of this labeling are considered separately
#   Possible assignments: [0]
#
#   Assign 0 to (6, [2, 1, 6])
#     New angle equation: +x0-90=0
#     Reduced angle equations:
#       {x0 = 90.0, x1 = -x2 - x3 + 270.0}
#     No new side equation
#
# This case has the following possibilities:
#   Assigning the angle in tile 6 incident to tiles [3, 2, 6, 7]
#     - to vertex 1 of T which has angle-type 'a'
#     - to vertex 2 of T which has angle-type 'o'
#       Impossible: The angles of this tile would be in the wrong order
#     - to vertex 3 of T which has angle-type 'a'
#   Possible assignments: [1, 3]
#
# Case 1.
#   Assign 1 to (6, [3, 2, 6, 7])
#     No new angle equation
#     New side equation: +x0-1.0=0
#     Reduced side equations:
#       {x0 = 1.00}
#
# Case 2.
#   Assign 3 to (6, [3, 2, 6, 7])
#     No new angle equation
#     New side equation: +x3-1.0=0
#     Reduced side equations:
#       {x3 = 1.00}
#
# Case 1. has the following possibilities:
#   Assigning the angle in tile 7 incident to tiles [3, 2, 6, 7]
#     - to vertex 0 of T which has angle-type 'r'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#     - to vertex 1 of T which has angle-type 'a'
#     - to vertex 2 of T which has angle-type 'o'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#     - to vertex 3 of T which has angle-type 'a'
#   Possible assignments: [1, 3]
#
# Case 1.1.
#   Assign 1 to (7, [3, 2, 6, 7])
#     New angle equation: +x1+x1-90=0
#     Reduced angle equations:
#       {x0 = 90.0, x1 = 45.0, x2 = 225.0 - x3}
#     No new side equation
#
# Case 1.2.
#   Assign 3 to (7, [3, 2, 6, 7])
#     New angle equation: +x1+x3-90=0
#     Reduced angle equations:
#       {x0 = 90.0, x1 = 90.0 - x3, x2 = 180.0}
#     Impossible: Angle-type of angle 2 is not 'o' (value 180.0)
#
# Case 2. has the following possibilities:
#   Assigning the angle in tile 7 incident to tiles [3, 2, 6, 7]
#     - to vertex 0 of T which has angle-type 'r'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#     - to vertex 1 of T which has angle-type 'a'
#     - to vertex 2 of T which has angle-type 'o'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#     - to vertex 3 of T which has angle-type 'a'
#   Possible assignments: [1, 3]
#
# Case 2.1.
#   Assign 1 to (7, [3, 2, 6, 7])
#     New angle equation: +x3+x1-90=0
#     Reduced angle equations:
#       {x0 = 90.0, x1 = 90.0 - x3, x2 = 180.0}
#     Impossible: Angle-type of angle 2 is not 'o' (value 180.0)
#
# Case 2.2.
#   Assign 3 to (7, [3, 2, 6, 7])
#     New angle equation: +x3+x3-90=0
#     Reduced angle equations:
#       {x0 = 90.0, x1 = 225.0 - x2, x3 = 45.0}
#     No new side equation
#
# Case 1.1. has the following possibilities:
#   Assigning the angle in tile 7 incident to tiles [4, 3, 7]
#     - to vertex 0 of T which has angle-type 'r'
#     - to vertex 2 of T which has angle-type 'o'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#     - to vertex 3 of T which has angle-type 'a'
#       Impossible: The angles of this tile would be in the wrong order
#   Possible assignments: [0]
#
# Case 1.1.1.
#   Assign 0 to (7, [4, 3, 7])
#     New angle equation: +x0-90=0
#     Reduced angle equations:
#       {x0 = 90.0, x1 = 45.0, x2 = 225.0 - x3}
#     New side equation: +x0-1.0=0
#     Reduced side equations:
#       {x0 = 1.00}
#
# Case 2.2. has the following possibilities:
#   Assigning the angle in tile 7 incident to tiles [4, 3, 7]
#     - to vertex 0 of T which has angle-type 'r'
#     - to vertex 1 of T which has angle-type 'a'
#       Impossible: The angles of this tile would be in the wrong order
#     - to vertex 2 of T which has angle-type 'o'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#   Possible assignments: [0]
#
# Case 2.2.1.
#   Assign 0 to (7, [4, 3, 7])
#     New angle equation: +x0-90=0
#     Reduced angle equations:
#       {x0 = 90.0, x1 = 225.0 - x2, x3 = 45.0}
#     New side equation: +x3-1.0=0
#     Reduced side equations:
#       {x3 = 1.00}
#
# Case 1.1.1. has the following possibilities:
#   Assigning the angle in tile 5 incident to tiles [1, 4, 5]
#     - to vertex 0 of T which has angle-type 'r'
#     - to vertex 1 of T which has angle-type 'a'
#       Impossible: Sum of angles at this tiling-vertex would be too small
#     - to vertex 2 of T which has angle-type 'o'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#     - to vertex 3 of T which has angle-type 'a'
#       Impossible: Sum of angles at this tiling-vertex would be too small
#   Possible assignments: [0]
#
# Case 1.1.1.1.
#   Assign 0 to (5, [1, 4, 5])
#     New angle equation: +x0-90=0
#     Reduced angle equations:
#       {x0 = 90.0, x1 = 45.0, x2 = 225.0 - x3}
#     No new side equation
#
# Case 2.2.1. has the following possibilities:
#   Assigning the angle in tile 5 incident to tiles [1, 4, 5]
#     - to vertex 0 of T which has angle-type 'r'
#     - to vertex 1 of T which has angle-type 'a'
#       Impossible: Sum of angles at this tiling-vertex would be too small
#     - to vertex 2 of T which has angle-type 'o'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#     - to vertex 3 of T which has angle-type 'a'
#       Impossible: Sum of angles at this tiling-vertex would be too small
#   Possible assignments: [0]
#
# Case 2.2.1.1.
#   Assign 0 to (5, [1, 4, 5])
#     New angle equation: +x0-90=0
#     Reduced angle equations:
#       {x0 = 90.0, x1 = 225.0 - x2, x3 = 45.0}
#     No new side equation
#
# Case 1.1.1.1. has the following possibilities:
#   Assigning the angle in tile 5 incident to tiles [1, 5, 6]
#     - to vertex 1 of T which has angle-type 'a'
#     - to vertex 2 of T which has angle-type 'o'
#       Impossible: The angles of this tile would be in the wrong order
#     - to vertex 3 of T which has angle-type 'a'
#   Possible assignments: [1, 3]
#
# Case 1.1.1.1.1.
#   Assign 1 to (5, [1, 5, 6])
#     No new angle equation
#     No new side equation
#
# Case 1.1.1.1.2.
#   Assign 3 to (5, [1, 5, 6])
#     No new angle equation
#     No new side equation
#
# Case 2.2.1.1. has the following possibilities:
#   Assigning the angle in tile 5 incident to tiles [1, 5, 6]
#     - to vertex 1 of T which has angle-type 'a'
#     - to vertex 2 of T which has angle-type 'o'
#       Impossible: The angles of this tile would be in the wrong order
#     - to vertex 3 of T which has angle-type 'a'
#   Possible assignments: [1, 3]
#
# Case 2.2.1.1.1.
#   Assign 1 to (5, [1, 5, 6])
#     No new angle equation
#     No new side equation
#
# Case 2.2.1.1.2.
#   Assign 3 to (5, [1, 5, 6])
#     No new angle equation
#     No new side equation
#
# Case 1.1.1.1.1. has the following possibilities:
#   Assigning the angle in tile 6 incident to tiles [1, 5, 6]
#     - to vertex 2 of T which has angle-type 'o'
#       The angles of this tile would be in the wrong order
#     - to vertex 3 of T which has angle-type 'a'
#       Impossible: Sum of angles at this tiling-vertex would be too small
#   Possible assignments: []
#
# Case 1.1.1.1.2. has the following possibilities:
#   Assigning the angle in tile 6 incident to tiles [1, 5, 6]
#     - to vertex 2 of T which has angle-type 'o'
#       The angles of this tile would be in the wrong order
#     - to vertex 3 of T which has angle-type 'a'
#       Impossible: Sum of angles at this tiling-vertex would be too small
#   Possible assignments: []
#
# Case 2.2.1.1.1. has the following possibilities:
#   Assigning the angle in tile 6 incident to tiles [1, 5, 6]
#     - to vertex 1 of T which has angle-type 'a'
#       Impossible: Sum of angles at this tiling-vertex would be too small
#     - to vertex 2 of T which has angle-type 'o'
#       The angles of this tile would be in the wrong order
#   Possible assignments: []
#
# Case 2.2.1.1.2. has the following possibilities:
#   Assigning the angle in tile 6 incident to tiles [1, 5, 6]
#     - to vertex 1 of T which has angle-type 'a'
#       Impossible: Sum of angles at this tiling-vertex would be too small
#     - to vertex 2 of T which has angle-type 'o'
#       The angles of this tile would be in the wrong order
#   Possible assignments: []
#
# Found 0 possible solutions.
#
# -------------------------------------------------
#
# Assuming T has labeling: raoo
#
#   Assigning the angle in tile 6 incident to tiles [2, 1, 6]
#     - to vertex 0 of T which has angle-type 'r'
#       Only this vertex of T is considered, cyclic permutations of this labeling are considered separately
#   Possible assignments: [0]
#
#   Assign 0 to (6, [2, 1, 6])
#     New angle equation: +x0-90=0
#     Reduced angle equations:
#       {x0 = 90.0, x1 = -x2 - x3 + 270.0}
#     No new side equation
#
# This case has the following possibilities:
#   Assigning the angle in tile 6 incident to tiles [3, 2, 6, 7]
#     - to vertex 1 of T which has angle-type 'a'
#     - to vertex 2 of T which has angle-type 'o'
#       Impossible: The angles of this tile would be in the wrong order
#     - to vertex 3 of T which has angle-type 'o'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#   Possible assignments: [1]
#
# Case 1.
#   Assign 1 to (6, [3, 2, 6, 7])
#     No new angle equation
#     New side equation: +x0-1.0=0
#     Reduced side equations:
#       {x0 = 1.00}
#
# Case 1. has the following possibilities:
#   Assigning the angle in tile 7 incident to tiles [3, 2, 6, 7]
#     - to vertex 0 of T which has angle-type 'r'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#     - to vertex 1 of T which has angle-type 'a'
#     - to vertex 2 of T which has angle-type 'o'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#     - to vertex 3 of T which has angle-type 'o'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#   Possible assignments: [1]
#
# Case 1.1.
#   Assign 1 to (7, [3, 2, 6, 7])
#     New angle equation: +x1+x1-90=0
#     Reduced angle equations:
#       {x0 = 90.0, x1 = 45.0, x2 = 225.0 - x3}
#     No new side equation
#
# Case 1.1. has the following possibilities:
#   Assigning the angle in tile 7 incident to tiles [4, 3, 7]
#     - to vertex 0 of T which has angle-type 'r'
#     - to vertex 2 of T which has angle-type 'o'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#     - to vertex 3 of T which has angle-type 'o'
#       Impossible: The angles of this tile would be in the wrong order
#   Possible assignments: [0]
#
# Case 1.1.1.
#   Assign 0 to (7, [4, 3, 7])
#     New angle equation: +x0-90=0
#     Reduced angle equations:
#       {x0 = 90.0, x1 = 45.0, x2 = 225.0 - x3}
#     New side equation: +x0-1.0=0
#     Reduced side equations:
#       {x0 = 1.00}
#
# Case 1.1.1. has the following possibilities:
#   Assigning the angle in tile 5 incident to tiles [1, 4, 5]
#     - to vertex 0 of T which has angle-type 'r'
#     - to vertex 1 of T which has angle-type 'a'
#       Impossible: Sum of angles at this tiling-vertex would be too small
#     - to vertex 2 of T which has angle-type 'o'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#     - to vertex 3 of T which has angle-type 'o'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#   Possible assignments: [0]
#
# Case 1.1.1.1.
#   Assign 0 to (5, [1, 4, 5])
#     New angle equation: +x0-90=0
#     Reduced angle equations:
#       {x0 = 90.0, x1 = 45.0, x2 = 225.0 - x3}
#     No new side equation
#
# Case 1.1.1.1. has the following possibilities:
#   Assigning the angle in tile 5 incident to tiles [1, 5, 6]
#     - to vertex 1 of T which has angle-type 'a'
#     - to vertex 2 of T which has angle-type 'o'
#       Impossible: The angles of this tile would be in the wrong order
#     - to vertex 3 of T which has angle-type 'o'
#   Possible assignments: [1, 3]
#
# Case 1.1.1.1.1.
#   Assign 1 to (5, [1, 5, 6])
#     No new angle equation
#     No new side equation
#
# Case 1.1.1.1.2.
#   Assign 3 to (5, [1, 5, 6])
#     No new angle equation
#     No new side equation
#
# Case 1.1.1.1.1. has the following possibilities:
#   Assigning the angle in tile 6 incident to tiles [1, 5, 6]
#     - to vertex 2 of T which has angle-type 'o'
#       The angles of this tile would be in the wrong order
#     - to vertex 3 of T which has angle-type 'o'
#   Possible assignments: [3]
#
# Case 1.1.1.1.1.1.
#   Assign 3 to (6, [1, 5, 6])
#     New angle equation: +x1+x3-180=0
#     Reduced angle equations:
#       {x0 = 90.0, x1 = 45.0, x2 = 90.0, x3 = 135.0}
#     Impossible: Angle-type of angle 2 is not 'o' (value 90.0)
#
# Case 1.1.1.1.2. has the following possibilities:
#   Assigning the angle in tile 6 incident to tiles [1, 5, 6]
#     - to vertex 2 of T which has angle-type 'o'
#       The angles of this tile would be in the wrong order
#     - to vertex 3 of T which has angle-type 'o'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#   Possible assignments: []
#
# Found 0 possible solutions.
#
# -------------------------------------------------
#
# Assuming T has labeling: roao
#
#   Assigning the angle in tile 6 incident to tiles [2, 1, 6]
#     - to vertex 0 of T which has angle-type 'r'
#       Only this vertex of T is considered, cyclic permutations of this labeling are considered separately
#   Possible assignments: [0]
#
#   Assign 0 to (6, [2, 1, 6])
#     New angle equation: +x0-90=0
#     Reduced angle equations:
#       {x0 = 90.0, x1 = -x2 - x3 + 270.0}
#     No new side equation
#
# This case has the following possibilities:
#   Assigning the angle in tile 6 incident to tiles [3, 2, 6, 7]
#     - to vertex 1 of T which has angle-type 'o'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#     - to vertex 2 of T which has angle-type 'a'
#       Impossible: The angles of this tile would be in the wrong order
#     - to vertex 3 of T which has angle-type 'o'
#       Impossible: Sum of angles at this tiling-vertex would be too large
#   Possible assignments: []
#
# Found 0 possible solutions.
#
# -------------------------------------------------
# []
