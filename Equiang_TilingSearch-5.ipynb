# %%
from definitions_equiang import *
num_cores = multiprocessing.cpu_count()

# %%
Graphs5 = load_plantri(filename='10pc3')
print(f'Loaded {len(Graphs5)} grahps from plantri.')
# Out:
# Loaded 32300 grahps from plantri.

# %%
inputs = tqdm(Graphs5)

if __name__ == "__main__":
    processed_list = Parallel(n_jobs=num_cores)(delayed(add_distinguished)(G) for G in inputs)

Graphs5 = [G for DGraph in processed_list for G in DGraph]

print(f'Constructed {len(Graphs5)} graphs with a distinguished vertex.')
# Out:
# 100%|██████████| 32300/32300 [00:06<00:00, 5304.56it/s]
# Constructed 5842 graphs with a distinguished vertex.

# %%
inputs = tqdm(Graphs5)

if __name__ == "__main__":
    processed_list = Parallel(n_jobs=num_cores)(delayed(second_filter)(G) for G in inputs)

Graphs5_3 = [Graphs5[i] for i in range(len(Graphs5)) if processed_list[i]]

print(f'Left with {len(Graphs5_3)} triangular graphs after filter.')
# Out:
# 100%|██████████| 5842/5842 [00:01<00:00, 3242.08it/s]
# Left with 1864 triangular graphs after filter.

# %%
inputs = tqdm(Graphs5)

if __name__ == "__main__":
    processed_list = Parallel(n_jobs=num_cores)(delayed(has_min_deg)(G, 4) for G in inputs)

Graphs5_4 = [Graphs5[i] for i in range(len(Graphs5)) if processed_list[i]]

print(f'There are {len(Graphs5_4)} quadrilateral graphs.')
# Out:
# 100%|██████████| 5842/5842 [00:01<00:00, 4934.79it/s]
# There are 107 quadrilateral graphs.

# %%
inputs = tqdm(Graphs5_4)

if __name__ == "__main__":
    processed_list = Parallel(n_jobs=num_cores)(delayed(has_min_deg)(G, 5) for G in inputs)

Graphs5_5 = [Graphs5_4[i] for i in range(len(Graphs5_4)) if processed_list[i]]

print(f'There are {len(Graphs5_5)} pentagonal graphs.')
# Out:
# 100%|██████████| 107/107 [00:00<00:00, 2286.31it/s]
# There are 0 pentagonal graphs.

# %%
save_ang_perms(3,'equiang_3_perms.txt', use5AT = True)

inputs = tqdm(Graphs5_3)

if __name__ == "__main__":
    processed_list = Parallel(n_jobs=num_cores)(delayed(search)(ig,G,'equiang_3_perms.txt', use5AT = True) for ig,G in enumerate(inputs))

FinalNodes_3 = [Nodes for Nodes in processed_list if len(Nodes)>0]

print(f'Left with {len(FinalNodes_3)} graphs after performing a deep search for each graph.')
# Out:
# 100%|██████████| 1864/1864 [01:00<00:00, 30.79it/s]
# Left with 15 graphs after performing a deep search for each graph.

# %%
save_ang_perms(4,'equiang_4_perms.txt')

inputs = tqdm(Graphs5_4)

if __name__ == "__main__":
    processed_list = Parallel(n_jobs=num_cores)(delayed(search)(ig,G,'equiang_4_perms.txt') for ig,G in enumerate(inputs))

FinalNodes_4 = [Nodes for Nodes in processed_list if len(Nodes)>0]

print(f'Left with {len(FinalNodes_4)} graphs after performing a deep search for each graph.')
# Out:
# 100%|██████████| 107/107 [00:29<00:00,  3.68it/s]
# Left with 27 graphs after performing a deep search for each graph.

# %%
P = load_ang_perms('equiang_3_perms.txt')
for N in FinalNodes_3:
    ig = N[0].iG
    Graphs5_3[ig].draw()
    print(f'Graph number {ig} has solutions with:')
    sols = []
    for G in N:
        a=solve(G.AngleEqs)
        if a not in sols:
            sols.append(a)
            print(a)
            print()
# Out:
# Graph number 26 has solutions with:
# {x0: 90.0 - x1, x2: 90.0000000000000}
# Graph number 28 has solutions with:
# {x0: 90.0 - x1, x2: 90.0000000000000}
# Graph number 80 has solutions with:
# {x0: 90.0 - x1, x2: 90.0000000000000}
# Graph number 119 has solutions with:
# {x0: 90.0000000000000, x1: 90.0 - x2}
# Graph number 279 has solutions with:
# {x0: 90.0000000000000, x1: 90.0 - x2}
# Graph number 472 has solutions with:
# {x0: 90.0 - x1, x2: 90.0000000000000}
# Graph number 510 has solutions with:
# {x0: 90.0 - x1, x2: 90.0000000000000}
#
# {x0: 45.0000000000000, x1: 45.0000000000000, x2: 90.0000000000000}
# Graph number 740 has solutions with:
# {x0: 90.0000000000000, x1: 90.0 - x2}
#
# {x0: 90.0000000000000, x1: 45.0000000000000, x2: 45.0000000000000}
# Graph number 891 has solutions with:
# {x0: 90.0000000000000, x1: 90.0 - x2}
#
# {x0: 90.0000000000000, x1: 45.0000000000000, x2: 45.0000000000000}
# Graph number 1118 has solutions with:
# {x0: 90.0000000000000, x1: 90.0 - x2}
#
# {x0: 90.0000000000000, x1: 45.0000000000000, x2: 45.0000000000000}
# Graph number 1159 has solutions with:
# {x0: 90.0 - x1, x2: 90.0000000000000}
#
# {x0: 45.0000000000000, x1: 45.0000000000000, x2: 90.0000000000000}
# Graph number 1295 has solutions with:
# {x0: 90.0 - x1, x2: 90.0000000000000}
# Graph number 1298 has solutions with:
# {x0: 90.0 - x1, x2: 90.0000000000000}
#
# {x0: 45.0000000000000, x1: 45.0000000000000, x2: 90.0000000000000}
# Graph number 1299 has solutions with:
# {x0: 90.0 - x1, x2: 90.0000000000000}
#
# {x0: 45.0000000000000, x1: 45.0000000000000, x2: 90.0000000000000}
# Graph number 1586 has solutions with:
# {x0: 90.0 - x1, x2: 90.0000000000000}

# %%
L = []
for N in FinalNodes_4:
    ig = N[0].iG
    L.append(Graphs5_4[ig])
    Graphs5_4[ig].draw()
    print(f'Graph number {ig} has solutions with:')
    sols = []
    for G in N:
        a=solve(G.AngleEqs)
        if a not in sols:
            sols.append(a)
            print(a)
            print()
# Out:
# Graph number 1 has solutions with:
# {x0: 90.0000000000000, x1: 180.0 - x2, x3: 90.0000000000000}
#
# {x0: 90.0000000000000, x1: 90.0000000000000, x2: 180.0 - x3}
# Graph number 2 has solutions with:
# {x0: 90.0000000000000, x1: 180.0 - x2, x3: 90.0000000000000}
#
# {x0: 90.0000000000000, x1: 90.0000000000000, x2: 180.0 - x3}
# Graph number 3 has solutions with:
# {x0: 90.0000000000000, x1: 180.0 - x2, x3: 90.0000000000000}
#
# {x0: 90.0000000000000, x1: 90.0000000000000, x2: 180.0 - x3}
# Graph number 6 has solutions with:
# {x0: 90.0000000000000, x1: 45.0000000000000, x2: 90.0000000000000, x3: 135.000000000000}
# Graph number 11 has solutions with:
# {x0: 45.0000000000000, x1: 90.0000000000000, x2: 90.0000000000000, x3: 135.000000000000}
# Graph number 37 has solutions with:
# {x0: 90.0000000000000, x1: 45.0000000000000, x2: 135.000000000000, x3: 90.0000000000000}
# Graph number 38 has solutions with:
# {x0: 90.0000000000000, x1: 180.0 - x2, x3: 90.0000000000000}
#
# {x0: 90.0000000000000, x1: 90.0000000000000, x2: 180.0 - x3}
# Graph number 39 has solutions with:
# {x0: 90.0000000000000, x1: 45.0000000000000, x2: 135.000000000000, x3: 90.0000000000000}
# Graph number 57 has solutions with:
# {x0: 90.0000000000000, x1: 180.0 - x2, x3: 90.0000000000000}
#
# {x0: 90.0000000000000, x1: 90.0000000000000, x2: 180.0 - x3}
# Graph number 58 has solutions with:
# {x0: 90.0000000000000, x1: 180.0 - x2, x3: 90.0000000000000}
#
# {x0: 90.0000000000000, x1: 90.0000000000000, x2: 180.0 - x3}
# Graph number 59 has solutions with:
# {x0: 90.0000000000000, x1: 180.0 - x2, x3: 90.0000000000000}
#
# {x0: 90.0000000000000, x1: 90.0000000000000, x2: 180.0 - x3}
# Graph number 60 has solutions with:
# {x0: 45.0000000000000, x1: 90.0000000000000, x2: 90.0000000000000, x3: 135.000000000000}
#
# {x0: 45.0000000000000, x1: 90.0000000000000, x2: 135.000000000000, x3: 90.0000000000000}
# Graph number 68 has solutions with:
# {x0: 90.0000000000000, x1: 45.0000000000000, x2: 135.000000000000, x3: 90.0000000000000}
# Graph number 72 has solutions with:
# {x0: 90.0000000000000, x1: 45.0000000000000, x2: 135.000000000000, x3: 90.0000000000000}
# Graph number 74 has solutions with:
# {x0: 90.0000000000000, x1: 180.0 - x2, x3: 90.0000000000000}
#
# {x0: 90.0000000000000, x1: 90.0000000000000, x2: 180.0 - x3}
# Graph number 75 has solutions with:
# {x0: 90.0000000000000, x1: 180.0 - x2, x3: 90.0000000000000}
#
# {x0: 90.0000000000000, x1: 90.0000000000000, x2: 180.0 - x3}
# Graph number 77 has solutions with:
# {x0: 90.0000000000000, x1: 180.0 - x2, x3: 90.0000000000000}
#
# {x0: 90.0000000000000, x1: 45.0000000000000, x2: 135.000000000000, x3: 90.0000000000000}
#
# {x0: 90.0000000000000, x1: 90.0000000000000, x2: 180.0 - x3}
# Graph number 78 has solutions with:
# {x0: 45.0000000000000, x1: 90.0000000000000, x2: 90.0000000000000, x3: 135.000000000000}
# Graph number 84 has solutions with:
# {x0: 90.0000000000000, x1: 180.0 - x2, x3: 90.0000000000000}
#
# {x0: 90.0000000000000, x1: 90.0000000000000, x2: 180.0 - x3}
# Graph number 87 has solutions with:
# {x0: 90.0000000000000, x1: 180.0 - x2, x3: 90.0000000000000}
#
# {x0: 90.0000000000000, x1: 90.0000000000000, x2: 180.0 - x3}
# Graph number 89 has solutions with:
# {x0: 90.0000000000000, x1: 45.0000000000000, x2: 135.000000000000, x3: 90.0000000000000}
#
# {x0: 90.0000000000000, x1: 90.0000000000000, x2: 45.0000000000000, x3: 135.000000000000}
# Graph number 91 has solutions with:
# {x0: 45.0000000000000, x1: 90.0000000000000, x2: 90.0000000000000, x3: 135.000000000000}
# Graph number 94 has solutions with:
# {x0: 45.0000000000000, x1: 90.0000000000000, x2: 90.0000000000000, x3: 135.000000000000}
# Graph number 100 has solutions with:
# {x0: 90.0000000000000, x1: 180.0 - x2, x3: 90.0000000000000}
#
# {x0: 90.0000000000000, x1: 90.0000000000000, x2: 180.0 - x3}
# Graph number 101 has solutions with:
# {x0: 90.0000000000000, x1: 180.0 - x2, x3: 90.0000000000000}
#
# {x0: 90.0000000000000, x1: 90.0000000000000, x2: 180.0 - x3}
# Graph number 104 has solutions with:
# {x0: 90.0000000000000, x1: 90.0000000000000, x2: 60.0000000000000, x3: 120.000000000000}
# Graph number 105 has solutions with:
# {x0: 90.0000000000000, x1: 45.0000000000000, x2: 135.000000000000, x3: 90.0000000000000}
